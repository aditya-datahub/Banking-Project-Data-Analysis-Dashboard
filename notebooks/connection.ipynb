# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import pandas as pd

#connect to server
connection = mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',
    password='Aditya@2032',
    database='banking_case' 
)

# %%
query = 'SELECT * FROM customer'

# %%
df = pd.read_sql(query, connection)
# Out:
# C:\Users\addys\AppData\Local\Temp\ipykernel_2852\1848774206.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)

# %%
connection.close()

# %%
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324    6/5/2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10/12/2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314   25/1/2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594   28/3/2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269   20/7/2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...
